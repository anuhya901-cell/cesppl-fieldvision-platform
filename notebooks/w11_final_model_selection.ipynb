# %% [markdown]
# # Week 11 – Final Model Selection
#
# ## Objective
#
# The goal of Week 11 is to perform two targeted interventions based on the Week 10 error analysis, compare them with the current best model (Run 04), and select the final production model for deployment.
#
# This notebook includes:
# - Run 05: Stronger lighting augmentation
# - Run 06: Increased backbone fine-tuning
# - Model comparison
# - Final model selection
# - Canonical run preparation
